# %% [markdown]
# <a href="https://colab.research.google.com/github/Org-Space-Medicine-Engineering-Design/project-lunar/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3+3
# Out:
# 6
